# %% [markdown]
# # prepare

# %%
from config import bucket_name, client
from pathlib import Path
import os

save_dir = Path("./data")
# check if folder exists, ok if it does
os.makedirs(save_dir, exist_ok=True)


def download_from_gcs(blob_name: str, save_path: Path):
    """Downloads a file from Google Cloud Storage"""
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    blob.download_to_filename(str(save_path))
    print(f"Downloaded {blob_name} to {save_path}")


def show_blob_info(blob):
    """Prints information about a blob in a single line"""
    print(f"Name: {blob.name}, Size: {blob.size}, Updated: {blob.updated}")

def download_blobs(blob_names:list[str] = None, save_dir=save_dir):
    """Downloads a list of blobs from Google Cloud Storage"""
    if blob_names is None:
        blob_names = [blob.name for blob in  client.list_blobs(bucket_name)]
        print(f"Downloading all blobs from {bucket_name}")

    for blob_name in blob_names:
        save_path = save_dir / blob_name
        download_from_gcs(blob_name, save_path)
        
def list_blob_names():
    """Lists all the blobs in a bucket"""
    bucket = client.bucket(bucket_name)
    blobs = bucket.list_blobs()
    for blob in blobs:
        show_blob_info(blob)

def delete_from_gcs(blob_name: str):
    """Deletes a file from Google Cloud Storage"""
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    blob.delete()
    print(f"Deleted {blob_name}")

def delete_blobs(blob_names:list[str] = None):
    """Deletes a list of blobs from Google Cloud Storage"""
    if blob_names is None:
        blob_names = [blob.name for blob in  client.list_blobs(bucket_name)]
        print(f"Deleting all blobs from {bucket_name}")

    for blob_name in blob_names:
        delete_from_gcs(blob_name)

# %%
# list_blob_names()
# download_blobs(["result_1.txt"])
# download_blobs()
# delete_blobs(["result_1.txt"])
# delete_blobs()
# Out:
# Deleting all blobs from sim-results-localization
# Deleted result_10.txt
# Deleted result_11.txt
# Deleted result_12.txt
# Deleted result_13.txt
# Deleted result_14.txt
# Deleted result_15.txt
# Deleted result_16.txt
# Deleted result_17.txt
# Deleted result_18.txt
# Deleted result_19.txt
# Deleted result_2.txt
# Deleted result_20.txt
# Deleted result_21.txt
# Deleted result_22.txt
# Deleted result_23.txt
# Deleted result_24.txt
# Deleted result_25.txt
# Deleted result_26.txt
# Deleted result_27.txt
# Deleted result_28.txt
# Deleted result_29.txt
# Deleted result_3.txt
# Deleted result_30.txt
# Deleted result_31.txt
# Deleted result_32.txt
# Deleted result_33.txt
# Deleted result_34.txt
# Deleted result_35.txt
# Deleted result_36.txt
# Deleted result_37.txt
# Deleted result_38.txt
# Deleted result_39.txt
# Deleted result_4.txt
# Deleted result_40.txt
# Deleted result_41.txt
# Deleted result_42.txt
# Deleted result_43.txt
# Deleted result_44.txt
# Deleted result_45.txt
# Deleted result_46.txt
# Deleted result_47.txt
# Deleted result_48.txt
# Deleted result_49.txt
# Deleted result_5.txt
# Deleted result_50.txt
# Deleted result_51.txt
# Deleted result_52.txt
# Deleted result_53.txt
# Deleted result_54.txt
# Deleted result_55.txt
# Deleted result_56.txt
# Deleted result_57.txt
# Deleted result_58.txt
# Deleted result_59.txt
# Deleted result_6.txt
# Deleted result_60.txt
# Deleted result_7.txt
# Deleted result_8.txt
# Deleted result_9.txt
